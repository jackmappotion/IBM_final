# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %%
# !pip install sqlalchemy==1.3.9
# Out:
# Collecting sqlalchemy==1.3.9
#   Downloading SQLAlchemy-1.3.9.tar.gz (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 14.1 MB/s eta 0:00:00m eta 0:00:010:00:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sqlalchemy
#   Building wheel for sqlalchemy (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [524 lines of output]
#       /opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/site-packages/setuptools/config/setupcfg.py:293: _DeprecatedConfig: Deprecated config in `setup.cfg`
#       !!
#
#               ********************************************************************************
#               The license_file parameter is deprecated, use license_files instead.
#
#               This deprecation is overdue, please update your project and remove deprecated
#               calls to avoid build errors in the future.
#
#               See https://setuptools.pypa.io/en/latest/userguide/declarative_config.html for details.
#               ********************************************************************************
#
#       !!
#         parsed = self.parsers.get(option_name, lambda x: x)(value)
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11.1-arm64-cpython-310
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy
#       copying lib/sqlalchemy/interfaces.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy
#       copying lib/sqlalchemy/log.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy
#       copying lib/sqlalchemy/events.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy
#       copying lib/sqlalchemy/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy
#       copying lib/sqlalchemy/types.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy
#       copying lib/sqlalchemy/inspection.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy
#       copying lib/sqlalchemy/exc.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy
#       copying lib/sqlalchemy/processors.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy
#       copying lib/sqlalchemy/schema.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/connectors
#       copying lib/sqlalchemy/connectors/mxodbc.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/connectors
#       copying lib/sqlalchemy/connectors/zxJDBC.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/connectors
#       copying lib/sqlalchemy/connectors/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/connectors
#       copying lib/sqlalchemy/connectors/pyodbc.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/connectors
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/databases
#       copying lib/sqlalchemy/databases/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/databases
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util
#       copying lib/sqlalchemy/util/queue.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util
#       copying lib/sqlalchemy/util/topological.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util
#       copying lib/sqlalchemy/util/compat.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util
#       copying lib/sqlalchemy/util/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util
#       copying lib/sqlalchemy/util/deprecations.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util
#       copying lib/sqlalchemy/util/_collections.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util
#       copying lib/sqlalchemy/util/langhelpers.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext
#       copying lib/sqlalchemy/ext/instrumentation.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext
#       copying lib/sqlalchemy/ext/compiler.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext
#       copying lib/sqlalchemy/ext/orderinglist.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext
#       copying lib/sqlalchemy/ext/hybrid.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext
#       copying lib/sqlalchemy/ext/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext
#       copying lib/sqlalchemy/ext/indexable.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext
#       copying lib/sqlalchemy/ext/serializer.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext
#       copying lib/sqlalchemy/ext/baked.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext
#       copying lib/sqlalchemy/ext/automap.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext
#       copying lib/sqlalchemy/ext/horizontal_shard.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext
#       copying lib/sqlalchemy/ext/mutable.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext
#       copying lib/sqlalchemy/ext/associationproxy.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/pickleable.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/exclusions.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/config.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/engines.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/util.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/warnings.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/assertions.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/replay_fixture.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/assertsql.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/provision.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/requirements.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/entities.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/profiling.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/fixtures.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/schema.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       copying lib/sqlalchemy/testing/mock.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects
#       copying lib/sqlalchemy/dialects/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/sync.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/interfaces.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/instrumentation.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/loading.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/persistence.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/path_registry.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/query.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/attributes.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/strategies.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/strategy_options.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/properties.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/util.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/events.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/mapper.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/scoping.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/session.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/dynamic.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/exc.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/collections.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/dependency.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/deprecated_interfaces.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/descriptor_props.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/identity.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/evaluator.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/unitofwork.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/base.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/relationships.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       copying lib/sqlalchemy/orm/state.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine
#       copying lib/sqlalchemy/engine/interfaces.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine
#       copying lib/sqlalchemy/engine/threadlocal.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine
#       copying lib/sqlalchemy/engine/strategies.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine
#       copying lib/sqlalchemy/engine/util.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine
#       copying lib/sqlalchemy/engine/reflection.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine
#       copying lib/sqlalchemy/engine/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine
#       copying lib/sqlalchemy/engine/url.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine
#       copying lib/sqlalchemy/engine/result.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine
#       copying lib/sqlalchemy/engine/default.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine
#       copying lib/sqlalchemy/engine/base.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/pool
#       copying lib/sqlalchemy/pool/dbapi_proxy.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/pool
#       copying lib/sqlalchemy/pool/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/pool
#       copying lib/sqlalchemy/pool/impl.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/pool
#       copying lib/sqlalchemy/pool/base.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/pool
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/event
#       copying lib/sqlalchemy/event/legacy.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/event
#       copying lib/sqlalchemy/event/registry.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/event
#       copying lib/sqlalchemy/event/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/event
#       copying lib/sqlalchemy/event/api.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/event
#       copying lib/sqlalchemy/event/attr.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/event
#       copying lib/sqlalchemy/event/base.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/event
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/functions.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/annotation.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/ddl.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/compiler.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/naming.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/util.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/visitors.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/default_comparator.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/elements.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/sqltypes.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/operators.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/selectable.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/dml.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/expression.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/base.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/type_api.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/crud.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       copying lib/sqlalchemy/sql/schema.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/declarative
#       copying lib/sqlalchemy/ext/declarative/clsregistry.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/declarative
#       copying lib/sqlalchemy/ext/declarative/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/declarative
#       copying lib/sqlalchemy/ext/declarative/api.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/declarative
#       copying lib/sqlalchemy/ext/declarative/base.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/declarative
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/plugin
#       copying lib/sqlalchemy/testing/plugin/bootstrap.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/plugin
#       copying lib/sqlalchemy/testing/plugin/plugin_base.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/plugin
#       copying lib/sqlalchemy/testing/plugin/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/plugin
#       copying lib/sqlalchemy/testing/plugin/pytestplugin.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/plugin
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite
#       copying lib/sqlalchemy/testing/suite/test_sequence.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite
#       copying lib/sqlalchemy/testing/suite/test_results.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite
#       copying lib/sqlalchemy/testing/suite/test_insert.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite
#       copying lib/sqlalchemy/testing/suite/test_select.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite
#       copying lib/sqlalchemy/testing/suite/test_ddl.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite
#       copying lib/sqlalchemy/testing/suite/test_dialect.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite
#       copying lib/sqlalchemy/testing/suite/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite
#       copying lib/sqlalchemy/testing/suite/test_update_delete.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite
#       copying lib/sqlalchemy/testing/suite/test_reflection.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite
#       copying lib/sqlalchemy/testing/suite/test_cte.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite
#       copying lib/sqlalchemy/testing/suite/test_types.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sybase
#       copying lib/sqlalchemy/dialects/sybase/mxodbc.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sybase
#       copying lib/sqlalchemy/dialects/sybase/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sybase
#       copying lib/sqlalchemy/dialects/sybase/pysybase.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sybase
#       copying lib/sqlalchemy/dialects/sybase/pyodbc.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sybase
#       copying lib/sqlalchemy/dialects/sybase/base.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sybase
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       copying lib/sqlalchemy/dialects/postgresql/zxjdbc.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       copying lib/sqlalchemy/dialects/postgresql/psycopg2cffi.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       copying lib/sqlalchemy/dialects/postgresql/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       copying lib/sqlalchemy/dialects/postgresql/pygresql.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       copying lib/sqlalchemy/dialects/postgresql/ranges.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       copying lib/sqlalchemy/dialects/postgresql/pypostgresql.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       copying lib/sqlalchemy/dialects/postgresql/psycopg2.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       copying lib/sqlalchemy/dialects/postgresql/pg8000.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       copying lib/sqlalchemy/dialects/postgresql/array.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       copying lib/sqlalchemy/dialects/postgresql/dml.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       copying lib/sqlalchemy/dialects/postgresql/json.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       copying lib/sqlalchemy/dialects/postgresql/base.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       copying lib/sqlalchemy/dialects/postgresql/ext.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       copying lib/sqlalchemy/dialects/postgresql/hstore.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/oracle
#       copying lib/sqlalchemy/dialects/oracle/zxjdbc.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/oracle
#       copying lib/sqlalchemy/dialects/oracle/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/oracle
#       copying lib/sqlalchemy/dialects/oracle/cx_oracle.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/oracle
#       copying lib/sqlalchemy/dialects/oracle/base.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/oracle
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sqlite
#       copying lib/sqlalchemy/dialects/sqlite/pysqlcipher.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sqlite
#       copying lib/sqlalchemy/dialects/sqlite/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sqlite
#       copying lib/sqlalchemy/dialects/sqlite/json.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sqlite
#       copying lib/sqlalchemy/dialects/sqlite/base.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sqlite
#       copying lib/sqlalchemy/dialects/sqlite/pysqlite.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sqlite
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/enumerated.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/oursql.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/mysqlconnector.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/reflection.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/zxjdbc.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/types.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/mysqldb.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/pymysql.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/gaerdbms.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/dml.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/json.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/pyodbc.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/base.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       copying lib/sqlalchemy/dialects/mysql/cymysql.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql
#       copying lib/sqlalchemy/dialects/mssql/mxodbc.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql
#       copying lib/sqlalchemy/dialects/mssql/zxjdbc.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql
#       copying lib/sqlalchemy/dialects/mssql/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql
#       copying lib/sqlalchemy/dialects/mssql/pymssql.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql
#       copying lib/sqlalchemy/dialects/mssql/adodbapi.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql
#       copying lib/sqlalchemy/dialects/mssql/information_schema.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql
#       copying lib/sqlalchemy/dialects/mssql/pyodbc.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql
#       copying lib/sqlalchemy/dialects/mssql/base.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql
#       creating build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/firebird
#       copying lib/sqlalchemy/dialects/firebird/__init__.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/firebird
#       copying lib/sqlalchemy/dialects/firebird/fdb.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/firebird
#       copying lib/sqlalchemy/dialects/firebird/kinterbasdb.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/firebird
#       copying lib/sqlalchemy/dialects/firebird/base.py -> build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/firebird
#       running build_ext
#       building 'sqlalchemy.cprocessors' extension
#       creating build/temp.macosx-11.1-arm64-cpython-310
#       creating build/temp.macosx-11.1-arm64-cpython-310/lib
#       creating build/temp.macosx-11.1-arm64-cpython-310/lib/sqlalchemy
#       creating build/temp.macosx-11.1-arm64-cpython-310/lib/sqlalchemy/cextension
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/homebrew/anaconda3/envs/quant_trading/include -arch arm64 -fPIC -O2 -isystem /opt/homebrew/anaconda3/envs/quant_trading/include -arch arm64 -I/opt/homebrew/anaconda3/envs/quant_trading/include/python3.10 -c lib/sqlalchemy/cextension/processors.c -o build/temp.macosx-11.1-arm64-cpython-310/lib/sqlalchemy/cextension/processors.o
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/homebrew/anaconda3/envs/quant_trading/lib -L/opt/homebrew/anaconda3/envs/quant_trading/lib -Wl,-rpath,/opt/homebrew/anaconda3/envs/quant_trading/lib -L/opt/homebrew/anaconda3/envs/quant_trading/lib build/temp.macosx-11.1-arm64-cpython-310/lib/sqlalchemy/cextension/processors.o -o build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/cprocessors.cpython-310-darwin.so
#       ld: warning: duplicate -rpath '/opt/homebrew/anaconda3/envs/quant_trading/lib' ignored
#       building 'sqlalchemy.cresultproxy' extension
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/homebrew/anaconda3/envs/quant_trading/include -arch arm64 -fPIC -O2 -isystem /opt/homebrew/anaconda3/envs/quant_trading/include -arch arm64 -I/opt/homebrew/anaconda3/envs/quant_trading/include/python3.10 -c lib/sqlalchemy/cextension/resultproxy.c -o build/temp.macosx-11.1-arm64-cpython-310/lib/sqlalchemy/cextension/resultproxy.o
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/homebrew/anaconda3/envs/quant_trading/lib -L/opt/homebrew/anaconda3/envs/quant_trading/lib -Wl,-rpath,/opt/homebrew/anaconda3/envs/quant_trading/lib -L/opt/homebrew/anaconda3/envs/quant_trading/lib build/temp.macosx-11.1-arm64-cpython-310/lib/sqlalchemy/cextension/resultproxy.o -o build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/cresultproxy.cpython-310-darwin.so
#       ld: warning: duplicate -rpath '/opt/homebrew/anaconda3/envs/quant_trading/lib' ignored
#       building 'sqlalchemy.cutils' extension
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/homebrew/anaconda3/envs/quant_trading/include -arch arm64 -fPIC -O2 -isystem /opt/homebrew/anaconda3/envs/quant_trading/include -arch arm64 -I/opt/homebrew/anaconda3/envs/quant_trading/include/python3.10 -c lib/sqlalchemy/cextension/utils.c -o build/temp.macosx-11.1-arm64-cpython-310/lib/sqlalchemy/cextension/utils.o
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/homebrew/anaconda3/envs/quant_trading/lib -L/opt/homebrew/anaconda3/envs/quant_trading/lib -Wl,-rpath,/opt/homebrew/anaconda3/envs/quant_trading/lib -L/opt/homebrew/anaconda3/envs/quant_trading/lib build/temp.macosx-11.1-arm64-cpython-310/lib/sqlalchemy/cextension/utils.o -o build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/cutils.cpython-310-darwin.so
#       ld: warning: duplicate -rpath '/opt/homebrew/anaconda3/envs/quant_trading/lib' ignored
#       /opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#       !!
#
#               ********************************************************************************
#               Please avoid running ``setup.py`` directly.
#               Instead, use pypa/build, pypa/installer or other
#               standards-based tools.
#
#               See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#               ********************************************************************************
#
#       !!
#         self.initialize_options()
#       installing to build/bdist.macosx-11.1-arm64/wheel
#       running install
#       running install_lib
#       creating build/bdist.macosx-11.1-arm64
#       creating build/bdist.macosx-11.1-arm64/wheel
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/interfaces.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/connectors
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/connectors/mxodbc.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/connectors
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/connectors/zxJDBC.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/connectors
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/connectors/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/connectors
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/connectors/pyodbc.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/connectors
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/databases
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/databases/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/databases
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/util
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util/queue.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/util
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util/topological.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/util
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util/compat.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/util
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/util
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util/deprecations.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/util
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util/_collections.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/util
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/util/langhelpers.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/util
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/log.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/events.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/instrumentation.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/compiler.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/orderinglist.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/hybrid.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/indexable.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext/declarative
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/declarative/clsregistry.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext/declarative
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/declarative/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext/declarative
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/declarative/api.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext/declarative
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/declarative/base.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext/declarative
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/serializer.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/baked.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/automap.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/horizontal_shard.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/mutable.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/ext/associationproxy.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/ext
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/types.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/inspection.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/cutils.cpython-310-darwin.so -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/pickleable.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/exclusions.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/config.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/engines.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/util.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/warnings.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/plugin
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/plugin/bootstrap.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/plugin
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/plugin/plugin_base.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/plugin
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/plugin/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/plugin
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/plugin/pytestplugin.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/plugin
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/assertions.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/replay_fixture.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/assertsql.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/provision.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/requirements.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/entities.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/suite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite/test_sequence.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/suite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite/test_results.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/suite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite/test_insert.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/suite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite/test_select.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/suite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite/test_ddl.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/suite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite/test_dialect.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/suite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/suite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite/test_update_delete.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/suite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite/test_reflection.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/suite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite/test_cte.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/suite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/suite/test_types.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing/suite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/profiling.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/fixtures.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/schema.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/testing/mock.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/testing
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/cprocessors.cpython-310-darwin.so -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/exc.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/sybase
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sybase/mxodbc.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/sybase
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sybase/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/sybase
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sybase/pysybase.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/sybase
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sybase/pyodbc.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/sybase
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sybase/base.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/sybase
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql/zxjdbc.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql/psycopg2cffi.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql/pygresql.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql/ranges.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql/pypostgresql.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql/psycopg2.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql/pg8000.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql/array.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql/dml.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql/json.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql/base.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql/ext.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/postgresql/hstore.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/postgresql
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/oracle
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/oracle/zxjdbc.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/oracle
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/oracle/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/oracle
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/oracle/cx_oracle.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/oracle
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/oracle/base.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/oracle
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/sqlite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sqlite/pysqlcipher.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/sqlite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sqlite/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/sqlite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sqlite/json.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/sqlite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sqlite/base.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/sqlite
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/sqlite/pysqlite.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/sqlite
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/enumerated.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/oursql.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/mysqlconnector.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/reflection.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/zxjdbc.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/types.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/mysqldb.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/pymysql.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/gaerdbms.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/dml.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/json.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/pyodbc.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/base.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mysql/cymysql.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mysql
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mssql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql/mxodbc.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mssql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql/zxjdbc.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mssql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mssql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql/pymssql.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mssql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql/adodbapi.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mssql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql/information_schema.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mssql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql/pyodbc.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mssql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/mssql/base.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/mssql
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/firebird
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/firebird/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/firebird
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/firebird/fdb.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/firebird
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/firebird/kinterbasdb.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/firebird
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/dialects/firebird/base.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/dialects/firebird
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/cresultproxy.cpython-310-darwin.so -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/processors.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/sync.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/interfaces.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/instrumentation.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/loading.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/persistence.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/path_registry.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/query.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/attributes.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/strategies.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/strategy_options.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/properties.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/util.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/events.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/mapper.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/scoping.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/session.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/dynamic.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/exc.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/collections.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/dependency.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/deprecated_interfaces.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/descriptor_props.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/identity.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/evaluator.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/unitofwork.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/base.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/relationships.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/orm/state.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/orm
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/engine
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine/interfaces.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/engine
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine/threadlocal.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/engine
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine/strategies.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/engine
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine/util.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/engine
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine/reflection.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/engine
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/engine
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine/url.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/engine
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine/result.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/engine
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine/default.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/engine
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/engine/base.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/engine
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/pool
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/pool/dbapi_proxy.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/pool
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/pool/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/pool
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/pool/impl.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/pool
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/pool/base.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/pool
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/event
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/event/legacy.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/event
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/event/registry.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/event
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/event/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/event
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/event/api.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/event
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/event/attr.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/event
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/event/base.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/event
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/schema.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy
#       creating build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/functions.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/annotation.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/ddl.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/compiler.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/naming.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/util.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/visitors.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/default_comparator.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/elements.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/__init__.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/sqltypes.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/operators.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/selectable.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/dml.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/expression.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/base.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/type_api.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/crud.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       copying build/lib.macosx-11.1-arm64-cpython-310/sqlalchemy/sql/schema.py -> build/bdist.macosx-11.1-arm64/wheel/sqlalchemy/sql
#       running install_egg_info
#       running egg_info
#       writing lib/SQLAlchemy.egg-info/PKG-INFO
#       writing dependency_links to lib/SQLAlchemy.egg-info/dependency_links.txt
#       writing requirements to lib/SQLAlchemy.egg-info/requires.txt
#       writing top-level names to lib/SQLAlchemy.egg-info/top_level.txt
#       reading manifest file 'lib/SQLAlchemy.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       no previously-included directories found matching 'doc/build/output'
#       adding license file 'LICENSE'
#       writing manifest file 'lib/SQLAlchemy.egg-info/SOURCES.txt'
#       Copying lib/SQLAlchemy.egg-info to build/bdist.macosx-11.1-arm64/wheel/SQLAlchemy-1.3.9-py3.10.egg-info
#       running install_scripts
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/c4/g1mnjj6x6d1_205z6bzrtjr80000gn/T/pip-install-htnibfbf/sqlalchemy_4b932926c6c94e6584d22d8deadbea67/setup.py", line 217, in <module>
#           run_setup(True)
#         File "/private/var/folders/c4/g1mnjj6x6d1_205z6bzrtjr80000gn/T/pip-install-htnibfbf/sqlalchemy_4b932926c6c94e6584d22d8deadbea67/setup.py", line 144, in run_setup
#           setup(
#         File "/opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/site-packages/setuptools/__init__.py", line 107, in setup
#           return distutils.core.setup(**attrs)
#         File "/opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/site-packages/setuptools/dist.py", line 1234, in run_command
#           super().run_command(command)
#         File "/opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 328, in run
#           impl_tag, abi_tag, plat_tag = self.get_tag()
#         File "/opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 278, in get_tag
#           assert tag in supported_tags, "would build wheel with unsupported tag {}".format(tag)
#       AssertionError: would build wheel with unsupported tag ('cp310', 'cp310', 'macosx_11_1_arm64')
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for sqlalchemy
#   Running setup.py clean for sqlalchemy
# Failed to build sqlalchemy
# ERROR: Could not build wheels for sqlalchemy, which is required to install pyproject.toml-based projects

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
#Please uncomment and execute the code below if you are working locally.

#!pip install ipython-sql

# %%
# %load_ext sql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_line_magic('load_ext', 'sql')
#
# File /opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
#    2434 # The code below prevents the output from being displayed
#    2435 # when using magics with decorator @output_can_be_silenced
#    2436 # when the last Python token in the expression is a ';'.
#    2437 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/site-packages/IPython/core/magics/extension.py:33, in ExtensionMagics.load_ext(self, module_str)
#      31 if not module_str:
#      32     raise UsageError('Missing module name.')
# ---> 33 res = self.shell.extension_manager.load_extension(module_str)
#      35 if res == 'already loaded':
#      36     print("The %s extension is already loaded. To reload it, use:" % module_str)
#
# File /opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/site-packages/IPython/core/extensions.py:76, in ExtensionManager.load_extension(self, module_str)
#      69 """Load an IPython extension by its module name.
#      70
#      71 Returns the string "already loaded" if the extension is already loaded,
#      72 "no load function" if the module doesn't have a load_ipython_extension
#      73 function, or None if it succeeded.
#      74 """
#      75 try:
# ---> 76     return self._load_extension(module_str)
#      77 except ModuleNotFoundError:
#      78     if module_str in BUILTINS_EXTS:
#
# File /opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/site-packages/IPython/core/extensions.py:91, in ExtensionManager._load_extension(self, module_str)
#      89 with self.shell.builtin_trap:
#      90     if module_str not in sys.modules:
# ---> 91         mod = import_module(module_str)
#      92     mod = sys.modules[module_str]
#      93     if self._call_load_ipython_extension(mod):
#
# File /opt/homebrew/anaconda3/envs/quant_trading/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'sql'

# %%
import csv, sqlite3

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas==1.1.5

# %%
# %sql sqlite:///my_data1.db

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# 101

# %% [markdown]
# **Note:This below code is added to remove blank rows from table**

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
# UsageError: Line magic function `%sql` not found.

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
#    For Example "Landing_Outcome"**
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
query = """
create 
    table 
        SPACEXTABLE as 
            select
                * 
            from 
                SPACEXTBL
            where 
                Date is not null
"""

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %% [markdown]
# ### Task 8
#
#
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %% [markdown]
# ### Task 9
#
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 6,2) as month to get the months and substr(Date,0,5)='2015' for year.**

# %% [markdown]
# ### Task 10
#
#
#
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order.

# %% [markdown]
# ### Reference Links
#
# * <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *  <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# ## Change log
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2021-07-09 | 0.2 |Lakshmi Holla | Changes made in magic sql|
# | 2021-05-20 | 0.1 |Lakshmi Holla | Created Initial Version |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
